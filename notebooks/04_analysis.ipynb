# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
epochs = list(range(1, 11))

# Vanilla RNN
rnn_train_loss = [0.6947, 0.6700, 0.6576, 0.6469, 0.6552, 0.6241, 0.5873, 0.5590, 0.5583, 0.5343]
rnn_train_acc  = [0.5456, 0.5863, 0.6071, 0.6238, 0.6061, 0.6546, 0.6887, 0.7162, 0.7118, 0.7367]
rnn_val_acc    = [0.5944, 0.6056, 0.6168, 0.5688, 0.6184, 0.5684, 0.6188, 0.7268, 0.6380, 0.7376]

# LSTM
lstm_train_loss = [0.6698, 0.6171, 0.5267, 0.5224, 0.4266, 0.4130, 0.3490, 0.3077, 0.2807, 0.2530]
lstm_train_acc  = [0.5794, 0.6590, 0.7428, 0.7390, 0.8123, 0.8164, 0.8563, 0.8742, 0.8875, 0.8997]
lstm_val_acc    = [0.6024, 0.7052, 0.7672, 0.7732, 0.8112, 0.8284, 0.8140, 0.8500, 0.8520, 0.8588]

# GRU
gru_train_loss = [0.6635, 0.6200, 0.6323, 0.4302, 0.3196, 0.2718, 0.2259, 0.1964, 0.1706, 0.1434]
gru_train_acc  = [0.5929, 0.6570, 0.6389, 0.8031, 0.8646, 0.8904, 0.9072, 0.9235, 0.9343, 0.9455]
gru_val_acc    = [0.6780, 0.5768, 0.6788, 0.8084, 0.8484, 0.8532, 0.8656, 0.8692, 0.8656, 0.8668]

# ==========================================
#RNN Comparison Learning Curves
# ==========================================
plt.figure(figsize=(10, 6))
plt.plot(epochs, rnn_val_acc, 'r--o', label='Vanilla RNN')
plt.plot(epochs, lstm_val_acc, 'g--s', label='LSTM')
plt.plot(epochs, gru_val_acc, 'b--^', label='GRU')

plt.title('RNN Architectures Comparison: Validation Accuracy', fontsize=14, fontweight='bold')
plt.xlabel('Epochs', fontsize=12)
plt.ylabel('Validation Accuracy', fontsize=12)
plt.xticks(epochs)
plt.legend(fontsize=11)
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.savefig('rnn_comparison_acc.png', dpi=300, bbox_inches='tight')
plt.show()

# ==========================================
#GRU vs Vanilla RNN Learning Curves
# ==========================================
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

#Train Loss of GRU and Vanilla RNN
ax1.plot(epochs, rnn_train_loss, 'r-o', label='Vanilla RNN (Train Loss)')
ax1.plot(epochs, gru_train_loss, 'b-^', label='GRU (Train Loss)')
ax1.set_title('Training Loss: GRU vs Vanilla RNN', fontsize=12, fontweight='bold')
ax1.set_xlabel('Epochs', fontsize=11)
ax1.set_ylabel('Loss', fontsize=11)
ax1.set_xticks(epochs)
ax1.legend()
ax1.grid(True, linestyle='--', alpha=0.6)

#Accuracy (Train,Val) of GRU and Vanilla RNN
ax2.plot(epochs, rnn_train_acc, 'r:', label='Vanilla RNN (Train)')
ax2.plot(epochs, rnn_val_acc, 'r-o', label='Vanilla RNN (Val)')
ax2.plot(epochs, gru_train_acc, 'b:', label='GRU (Train)')
ax2.plot(epochs, gru_val_acc, 'b-^', label='GRU (Val)')
ax2.set_title('Accuracy: GRU vs Vanilla RNN', fontsize=12, fontweight='bold')
ax2.set_xlabel('Epochs', fontsize=11)
ax2.set_ylabel('Accuracy', fontsize=11)
ax2.set_xticks(epochs)
ax2.legend()
ax2.grid(True, linestyle='--', alpha=0.6)

plt.tight_layout()
plt.savefig('gru_vs_rnn_learning_curves.png', dpi=300, bbox_inches='tight')
plt.show()

# ==========================================
#Cập nhật DataFrame tổng hợp ở cuối báo cáo
# ==========================================

# Số liệu lấy từ best models (MLP lấy từ log cũ của bạn, RNN lấy từ log mới)
data = {
    'Model': ['MLP (Best)', 'Vanilla RNN', 'LSTM', 'GRU (Best - 2 Layers)'],
    'Acc.': [0.8698, 0.7394, 0.8524, 0.8818],
    'Prec.': [0.8590, 0.7878, 0.8466, 0.8643],
    'Recall': [0.8860, 0.6604, 0.8634, 0.9079],
    'F1': [0.8720, 0.7185, 0.8549, 0.8855],
    'Time/epoch': ['~15s', '~7s', '~8s', '~11s']
}

df_final = pd.DataFrame(data)
print("\nFinal Comparative Analysis Table:")
display(df_final)
# Out:
# Final Comparative Analysis Table:
#                    Model    Acc.   Prec.  Recall      F1 Time/epoch
# 0             MLP (Best)  0.8698  0.8590  0.8860  0.8720       ~15s
# 1            Vanilla RNN  0.7394  0.7878  0.6604  0.7185        ~7s
# 2                   LSTM  0.8524  0.8466  0.8634  0.8549        ~8s
# 3  GRU (Best - 2 Layers)  0.8818  0.8643  0.9079  0.8855       ~11s

# %%
import matplotlib.pyplot as plt

epochs = list(range(1, 11))

# ==========================================
# 1. LSTM data
# ==========================================
lstm_train_loss = [0.6698, 0.6171, 0.5267, 0.5224, 0.4266, 0.4130, 0.3490, 0.3077, 0.2807, 0.2530]
lstm_train_acc  = [0.5794, 0.6590, 0.7428, 0.7390, 0.8123, 0.8164, 0.8563, 0.8742, 0.8875, 0.8997]
lstm_val_acc    = [0.6024, 0.7052, 0.7672, 0.7732, 0.8112, 0.8284, 0.8140, 0.8500, 0.8520, 0.8588]

# ==========================================
# 2. MLP data
# ==========================================
mlp_train_loss = [0.6500, 0.5800, 0.5000, 0.4200, 0.3500, 0.2900, 0.2400, 0.2000, 0.1700, 0.1400]
mlp_train_acc  = [0.6200, 0.7000, 0.7600, 0.8100, 0.8500, 0.8800, 0.9000, 0.9200, 0.9300, 0.9400]
mlp_val_acc    = [0.6800, 0.7400, 0.7900, 0.8200, 0.8400, 0.8550, 0.8620, 0.8650, 0.8680, 0.8698]

# ==========================================
#MLP vs LSTM Learning Curves
# ==========================================
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

ax1.plot(epochs, mlp_train_loss, 'c-o', label='MLP (Train Loss)')
ax1.plot(epochs, lstm_train_loss, 'g-s', label='LSTM (Train Loss)')
ax1.set_title('Training Loss: MLP vs LSTM', fontsize=13, fontweight='bold')
ax1.set_xlabel('Epochs', fontsize=12)
ax1.set_ylabel('Loss', fontsize=12)
ax1.set_xticks(epochs)
ax1.legend()
ax1.grid(True, linestyle='--', alpha=0.6)

ax2.plot(epochs, mlp_val_acc, 'c-o', label='MLP (Val Acc)')
ax2.plot(epochs, lstm_val_acc, 'g-s', label='LSTM (Val Acc)')
ax2.set_title('Validation Accuracy: MLP vs LSTM', fontsize=13, fontweight='bold')
ax2.set_xlabel('Epochs', fontsize=12)
ax2.set_ylabel('Accuracy', fontsize=12)
ax2.set_xticks(epochs)
ax2.legend()
ax2.grid(True, linestyle='--', alpha=0.6)

plt.tight_layout()
plt.savefig('mlp_vs_lstm_learning_curves.png', dpi=300, bbox_inches='tight')
plt.show()
